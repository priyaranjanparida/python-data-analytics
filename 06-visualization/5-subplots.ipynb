# %% [markdown]
# # Subplots
#
# Displaying graphs side by side
#
# References

# %% [markdown]
# ## 1 - Load Data
#
# data from : https://github.com/nickmccullum/python-visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import os
import urllib.request

data_location = '../data/GOOG_MSFT_FB_AMZN_data.csv'
data_url = 'https://raw.githubusercontent.com/elephantscale/datasets/master/stocks/GOOG_MSFT_FB_AMZN_data.csv'
# data_url = 'https://raw.githubusercontent.com/nicholasmccullum/python-visualization/master/tech_stocks/GOOG_MSFT_FB_AMZN_data.csv'

if not os.path.exists (data_location):
    data_location = os.path.basename(data_location)
    if not os.path.exists(data_location):
        print("Downloading : ", data_url)
        urllib.request.urlretrieve(data_url, data_location)
print('data_location:', data_location)
# Out:
# data_location: ../data/GOOG_MSFT_FB_AMZN_data.csv

# %%
stocks = pd.read_csv(data_location)

# cut down data size, it will make graphs render quickly :-)
stocks = stocks.sample(100)

# sort them by time order
stocks.sort_values('Period', ascending = True, inplace = True)
stocks
# Out:
#                    Period  Alphabet Inc Price  Amazon.com Inc Price  \
# 1260  2015-04-10 00:00:00          538.531730                382.65
# 1259  2015-04-13 00:00:00          537.694030                382.36
# 1253  2015-04-21 00:00:00          532.508265                391.18
# 1224  2015-06-02 00:00:00          539.180000                430.99
# 1221  2015-06-05 00:00:00          533.330000                426.95
# ...                   ...                 ...                   ...
# 78    2019-12-16 00:00:00         1361.170000               1769.21
# 55    2020-01-21 00:00:00         1484.400000               1892.00
# 34    2020-02-20 00:00:00         1518.150000               2153.10
# 8     2020-03-27 00:00:00         1110.710000               1900.10
# 3     2020-04-03 00:00:00         1097.880000               1906.59
#
#       Facebook Inc Price  Microsoft Corp Price
# 1260              82.040                41.720
# 1259              83.010                41.760
# 1253              83.620                42.635
# 1224              80.445                46.920
# 1221              82.140                46.140
# ...                  ...                   ...
# 78               197.920               155.530
# 55               221.440               166.500
# 34               214.580               184.420
# 8                156.790               149.700
# 3                154.180               153.830
#
# [100 rows x 5 columns]

# %% [markdown]
# ## 2 - Start with one graph

# %%
sns.scatterplot(data=stocks, x='Period', y='Alphabet Inc Price')
# Out:
# <AxesSubplot: xlabel='Period', ylabel='Alphabet Inc Price'>

# %% [markdown]
# ## 3 - Let's Create a Grid
#
# This is done via  `plt.subplots`
#
# - first argument is number of rows
# - second argument is number of columns

# %%
plt.rcParams["figure.figsize"] = (10,5)  # <-- set size

fig, axes = plt.subplots(1, 2)  # <-- row=1, cols=2
plt.show()  # empty plots for now

# %% [markdown]
# ## 5 - Add plots to the grids

# %%
plt.rcParams["figure.figsize"] = (15,5)  # <-- set size

fig, axes = plt.subplots(1, 2)  # <-- row=1,  col=2


sns.scatterplot(data=stocks, x='Period', color="red", y='Alphabet Inc Price', ax=axes[0])
sns.scatterplot(data=stocks, x='Period', color="green", y='Amazon.com Inc Price', ax=axes[1])

plt.show()  # empty plots for now

# %% [markdown]
# ## 6 - Stack Vertically

# %%
plt.rcParams["figure.figsize"] = (10,5)  # <-- set size

fig, axes = plt.subplots(2, 1)  # <-- row=2,  col=1


sns.scatterplot(data=stocks, x='Period', color="red", y='Alphabet Inc Price', ax=axes[0])
sns.scatterplot(data=stocks, x='Period', color="green", y='Amazon.com Inc Price', ax=axes[1])

plt.show()  # empty plots for now

# %% [markdown]
# ## 7 - Let's do a 4x4 grid
#
# **Note: how the the axes are referred as 2D array**

# %%
plt.rcParams["figure.figsize"] = (15,5)  # <-- set size

fig, axes = plt.subplots(2, 2)  # <-- row=2,  col=2

sns.scatterplot(data=stocks, x='Period', color="red", y='Alphabet Inc Price', ax=axes[0][0])
sns.scatterplot(data=stocks, x='Period', color="green", y='Amazon.com Inc Price', ax=axes[0][1])
sns.scatterplot(data=stocks, x='Period', color="blue", y='Facebook Inc Price', ax=axes[1][0])
sns.scatterplot(data=stocks, x='Period', color="orange", y='Microsoft Corp Price', ax=axes[1][1])

plt.show()  # empty plots for now

# %% [markdown]
# ## Exercise
#
# Let's load up some dataset that you are familiar with. And let's compare them side by side

# %%
data_location = '../data/Life-Expectancy-Data.csv'

df = pd.read_csv(data_location)
df.sample(10)
# Out:
#          Country  Year      Status  Life expectancy   Adult Mortality  \
# 816        Egypt  2001  Developing              68.6            177.0
# 1086      Guinea  2003  Developing              53.3            338.0
# 86     Argentina  2009  Developing              75.6            126.0
# 1734  Montenegro  2013  Developing              75.8             19.0
# 858      Eritrea  2007  Developing              62.0            329.0
# 1285       Italy  2012   Developed              82.0              6.0
# 2449   Sri Lanka  2007  Developing              73.7            146.0
# 986      Georgia  2007  Developing              74.4             12.0
# 2155      Rwanda  2011  Developing              63.8            247.0
# 2924    Zimbabwe  2013  Developing              58.0            399.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 816              63     0.14                0.000000         99.0      2150
# 1086             34     0.18                2.395241          NaN      2497
# 86               10     8.33             1398.042623         94.0         3
# 1734              0     0.01              707.144691          9.0         0
# 858               6     1.23               11.423860         91.0        55
# 1285              2     7.49             4793.904924         96.0       376
# 2449              4     2.29              127.637750         98.0        44
# 986               1     8.65              106.164686         94.0        44
# 2155             14     8.34                9.074569         97.0        31
# 2924             25     6.39               10.666707         95.0         0
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS           GDP  \
# 816   ...   99.0               5.75         99.0        0.1           NaN
# 1086  ...   61.0               3.45         57.0        2.9     37.193178
# 86    ...   97.0               7.63         94.0        0.1   8161.369660
# 1734  ...   94.0               6.43         94.0        0.1   7186.429787
# 858   ...   91.0               3.29         91.0        1.3    317.329434
# 1285  ...   96.0               9.28         97.0        0.1  34814.124360
# 2449  ...   98.0               3.76         98.0        0.1   1644.816372
# 986   ...   88.0               8.17         98.0        0.1   2492.128780
# 2155  ...   93.0               7.71         97.0        1.3    617.317648
# 2924  ...   95.0               6.88         95.0        6.8    111.227396
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 816          NaN                    3.5                  3.4
# 1086    939848.0                    9.7                  9.7
# 86      479947.0                    1.0                  0.9
# 1734     62127.0                    1.8                  1.9
# 858    4153332.0                    9.2                  9.2
# 1285  59539717.0                    0.5                  0.6
# 2449     19668.0                   15.4                 15.5
# 986        482.0                    2.7                  2.9
# 2155    151671.0                    6.3                  6.2
# 2924    155456.0                    6.2                  6.0
#
#       Income composition of resources  Schooling
# 816                             0.612       11.1
# 1086                            0.338        5.9
# 86                              0.794       16.5
# 1734                            0.799       15.1
# 858                             0.405        5.3
# 1285                            0.877       16.6
# 2449                            0.725       13.2
# 986                             0.722       12.5
# 2155                            0.464       10.2
# 2924                            0.488       10.4
#
# [10 rows x 22 columns]

# %%
# Let's extra country, year and GDP

df2 = df[['Country', 'Year', 'GDP']]
df2
# Out:
#           Country  Year         GDP
# 0     Afghanistan  2015  584.259210
# 1     Afghanistan  2014  612.696514
# 2     Afghanistan  2013  631.744976
# 3     Afghanistan  2012  669.959000
# 4     Afghanistan  2011   63.537231
# ...           ...   ...         ...
# 2933     Zimbabwe  2004  454.366654
# 2934     Zimbabwe  2003  453.351155
# 2935     Zimbabwe  2002   57.348340
# 2936     Zimbabwe  2001  548.587312
# 2937     Zimbabwe  2000  547.358878
#
# [2938 rows x 3 columns]

# %%
# do a GDP graph like this for a Afghanistan
sns.scatterplot (data=df2.loc[df2['Country'] == 'Afghanistan'] , x='Year', y='GDP')
# Out:
# <AxesSubplot: xlabel='Year', ylabel='GDP'>

# %%
## TODO-1 : Now select another country and do a plot top/bottom

# %%
## TODO-2 : make it a 3x2 plot with 6 countries
