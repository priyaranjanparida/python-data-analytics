# %% [markdown]
# # Dealing with unclean data
#
# We're going to look at data that may require some cleansing.

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ## Read the admissions data that is not so clean

# %%
data_location = "../data/admission-data-dirty.csv"
if not os.path.exists (data_location):
    data_location = 'https://github.com/elephantscale/datasets/raw/master/college-admissions/admission-data-dirty.csv'
print('data_location:', data_location)
    
admissions = pd.read_csv(data_location)

print ("admissions shape : ", admissions.shape)
admissions
# Out:
# data_location: ../data/admission-data-dirty.csv
# admissions shape :  (20, 4)
#     admit    gre   gpa rank
# 0     1.0  400.0  3.23    4
# 1     1.0  700.0  3.56    1
# 2     1.0  800.0  4.00    2
# 3     0.0  500.0  3.53    4
# 4     0.0  560.0  3.78    2
# 5     0.0    NaN  3.35  NaN
# 6     1.0  520.0   NaN    3
# 7     0.0  440.0  3.17    2
# 8     1.0  760.0  3.00    2
# 9     NaN  600.0  2.82    4
# 10    1.0  500.0  3.60    3
# 11    0.0  500.0  3.95    4
# 12    NaN  680.0  3.27    2
# 13    1.0  560.0  3.59    2
# 14    0.0  700.0  3.65    2
# 15    0.0  520.0  2.98    2
# 16    0.0  700.0  3.92    2
# 17    1.0  620.0  4.00    x
# 18    0.0  640.0  3.51    2
# 19    1.0  600.0  3.58    1

# %% [markdown]
# ## Get Summary
# See what we get.  It will skip null values

# %%
admissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   admit   18 non-null     float64
#  1   gre     19 non-null     float64
#  2   gpa     19 non-null     float64
#  3   rank    19 non-null     object
# dtypes: float64(3), object(1)
# memory usage: 768.0+ bytes

# %% [markdown]
# ### Count Nulls per column

# %%
admissions.isnull().sum()
# Out:
# admit    2
# gre      1
# gpa      1
# rank     1
# dtype: int64

# %%
admissions.describe(include = 'all')
# Out:
#             admit         gre        gpa rank
# count   18.000000   19.000000  19.000000   19
# unique        NaN         NaN        NaN    5
# top           NaN         NaN        NaN    2
# freq          NaN         NaN        NaN   10
# mean     0.500000  594.736842   3.499474  NaN
# std      0.514496  109.309368   0.353467  NaN
# min      0.000000  400.000000   2.820000  NaN
# 25%      0.000000  510.000000   3.250000  NaN
# 50%      0.500000  600.000000   3.560000  NaN
# 75%      1.000000  690.000000   3.715000  NaN
# max      1.000000  800.000000   4.000000  NaN

# %%
## TODO : Describe more than one column : gre and gpa
## Hint : add 'gpa' column
admissions[['gre', 'gpa']].describe()
# Out:
#               gre        gpa
# count   19.000000  19.000000
# mean   594.736842   3.499474
# std    109.309368   0.353467
# min    400.000000   2.820000
# 25%    510.000000   3.250000
# 50%    600.000000   3.560000
# 75%    690.000000   3.715000
# max    800.000000   4.000000

# %% [markdown]
# ## Drop all null values

# %%
print("raw data shape : ", admissions.shape)
dropped_na = admissions.dropna()
print()
print("after drop shape : ", dropped_na.shape)
dropped_na
# Out:
# raw data shape :  (20, 4)
#
# after drop shape :  (16, 4)
#     admit    gre   gpa rank
# 0     1.0  400.0  3.23    4
# 1     1.0  700.0  3.56    1
# 2     1.0  800.0  4.00    2
# 3     0.0  500.0  3.53    4
# 4     0.0  560.0  3.78    2
# 7     0.0  440.0  3.17    2
# 8     1.0  760.0  3.00    2
# 10    1.0  500.0  3.60    3
# 11    0.0  500.0  3.95    4
# 13    1.0  560.0  3.59    2
# 14    0.0  700.0  3.65    2
# 15    0.0  520.0  2.98    2
# 16    0.0  700.0  3.92    2
# 17    1.0  620.0  4.00    x
# 18    0.0  640.0  3.51    2
# 19    1.0  600.0  3.58    1

# %%
# only drop nulls from admit & gre column
print("raw data shape : ", admissions.shape)

print()

dropped2 = admissions.dropna(subset=['admit', 'gre'])
print("after drop shape : ", dropped2.shape)
dropped2
# Out:
# raw data shape :  (20, 4)
#
# after drop shape :  (17, 4)
#     admit    gre   gpa rank
# 0     1.0  400.0  3.23    4
# 1     1.0  700.0  3.56    1
# 2     1.0  800.0  4.00    2
# 3     0.0  500.0  3.53    4
# 4     0.0  560.0  3.78    2
# 6     1.0  520.0   NaN    3
# 7     0.0  440.0  3.17    2
# 8     1.0  760.0  3.00    2
# 10    1.0  500.0  3.60    3
# 11    0.0  500.0  3.95    4
# 13    1.0  560.0  3.59    2
# 14    0.0  700.0  3.65    2
# 15    0.0  520.0  2.98    2
# 16    0.0  700.0  3.92    2
# 17    1.0  620.0  4.00    x
# 18    0.0  640.0  3.51    2
# 19    1.0  600.0  3.58    1

# %% [markdown]
# ## Fill in the values

# %%
# fill every thing with zero
zero_fill = admissions.fillna(0)
zero_fill
# Out:
#     admit    gre   gpa rank
# 0     1.0  400.0  3.23    4
# 1     1.0  700.0  3.56    1
# 2     1.0  800.0  4.00    2
# 3     0.0  500.0  3.53    4
# 4     0.0  560.0  3.78    2
# 5     0.0    0.0  3.35    0
# 6     1.0  520.0  0.00    3
# 7     0.0  440.0  3.17    2
# 8     1.0  760.0  3.00    2
# 9     0.0  600.0  2.82    4
# 10    1.0  500.0  3.60    3
# 11    0.0  500.0  3.95    4
# 12    0.0  680.0  3.27    2
# 13    1.0  560.0  3.59    2
# 14    0.0  700.0  3.65    2
# 15    0.0  520.0  2.98    2
# 16    0.0  700.0  3.92    2
# 17    1.0  620.0  4.00    x
# 18    0.0  640.0  3.51    2
# 19    1.0  600.0  3.58    1

# %%
# or we can specify per column default value
## TODO : specify different default values per column
fill2 = admissions.fillna({'admit': -1, 
                           'gre':admissions['gre'].mean() , 
                           'gpa':admissions['gpa'].mean(), 
                           'rank':10})
fill2
# Out:
#     admit         gre       gpa rank
# 0     1.0  400.000000  3.230000    4
# 1     1.0  700.000000  3.560000    1
# 2     1.0  800.000000  4.000000    2
# 3     0.0  500.000000  3.530000    4
# 4     0.0  560.000000  3.780000    2
# 5     0.0  594.736842  3.350000   10
# 6     1.0  520.000000  3.499474    3
# 7     0.0  440.000000  3.170000    2
# 8     1.0  760.000000  3.000000    2
# 9    -1.0  600.000000  2.820000    4
# 10    1.0  500.000000  3.600000    3
# 11    0.0  500.000000  3.950000    4
# 12   -1.0  680.000000  3.270000    2
# 13    1.0  560.000000  3.590000    2
# 14    0.0  700.000000  3.650000    2
# 15    0.0  520.000000  2.980000    2
# 16    0.0  700.000000  3.920000    2
# 17    1.0  620.000000  4.000000    x
# 18    0.0  640.000000  3.510000    2
# 19    1.0  600.000000  3.580000    1

# %% [markdown]
# ## Replace values

# %%
print (admissions)

admissions2 = admissions.copy(deep=True)
admissions2['gre'].replace(800, 1000, inplace=True)

print()
print (admissions2)
# Out:
#     admit    gre   gpa rank
# 0     1.0  400.0  3.23    4
# 1     1.0  700.0  3.56    1
# 2     1.0  800.0  4.00    2
# 3     0.0  500.0  3.53    4
# 4     0.0  560.0  3.78    2
# 5     0.0    NaN  3.35  NaN
# 6     1.0  520.0   NaN    3
# 7     0.0  440.0  3.17    2
# 8     1.0  760.0  3.00    2
# 9     NaN  600.0  2.82    4
# 10    1.0  500.0  3.60    3
# 11    0.0  500.0  3.95    4
# 12    NaN  680.0  3.27    2
# 13    1.0  560.0  3.59    2
# 14    0.0  700.0  3.65    2
# 15    0.0  520.0  2.98    2
# 16    0.0  700.0  3.92    2
# 17    1.0  620.0  4.00    x
# 18    0.0  640.0  3.51    2
# 19    1.0  600.0  3.58    1
#
#     admit     gre   gpa rank
# 0     1.0   400.0  3.23    4
# 1     1.0   700.0  3.56    1
# 2     1.0  1000.0  4.00    2
# 3     0.0   500.0  3.53    4
# 4     0.0   560.0  3.78    2
# 5     0.0     NaN  3.35  NaN
# 6     1.0   520.0   NaN    3
# 7     0.0   440.0  3.17    2
# 8     1.0   760.0  3.00    2
# 9     NaN   600.0  2.82    4
# 10    1.0   500.0  3.60    3
# 11    0.0   500.0  3.95    4
# 12    NaN   680.0  3.27    2
# 13    1.0   560.0  3.59    2
# 14    0.0   700.0  3.65    2
# 15    0.0   520.0  2.98    2
# 16    0.0   700.0  3.92    2
# 17    1.0   620.0  4.00    x
# 18    0.0   640.0  3.51    2
# 19    1.0   600.0  3.58    1

# %% [markdown]
# ## Clean out RANK column

# %%
admissions3 = admissions[admissions['rank'].isin(['1','2','3','4'])]
admissions3
# Out:
#     admit    gre   gpa rank
# 0     1.0  400.0  3.23    4
# 1     1.0  700.0  3.56    1
# 2     1.0  800.0  4.00    2
# 3     0.0  500.0  3.53    4
# 4     0.0  560.0  3.78    2
# 6     1.0  520.0   NaN    3
# 7     0.0  440.0  3.17    2
# 8     1.0  760.0  3.00    2
# 9     NaN  600.0  2.82    4
# 10    1.0  500.0  3.60    3
# 11    0.0  500.0  3.95    4
# 12    NaN  680.0  3.27    2
# 13    1.0  560.0  3.59    2
# 14    0.0  700.0  3.65    2
# 15    0.0  520.0  2.98    2
# 16    0.0  700.0  3.92    2
# 18    0.0  640.0  3.51    2
# 19    1.0  600.0  3.58    1
