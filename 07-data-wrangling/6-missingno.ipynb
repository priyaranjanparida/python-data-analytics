# %% [markdown]
# # MissingNo library for Cleanup
#
# [missingno library](https://pypi.org/project/missingno/)
#
# Install it as follows:
#
# ```bash
# # for conda
# $  conda install missingno
#
# # or for pip
# $  pip install missingno
# ```
#
# ## References
#
# - [Oil well log analysis](https://towardsdatascience.com/using-the-missingno-python-library-to-identify-and-visualise-missing-data-prior-to-machine-learning-34c8c5b5f009)
# * [Streaming platform analysis](https://towardsdatascience.com/4-must-know-libraries-in-pandas-ecosystem-7c01326c4724)

# %% [markdown]
# ## Read Data - Streaming Movies

# %%
import pandas as pd

## Well log data : https://zenodo.org/record/4351156
data_location = '../data/xeek-sample.csv'

# data_location = 'https://github.com/elephantscale/datasets/blob/master/misc/xeek-sample.csv?raw=true'

# larger data
# data_location = 'https://github.com/elephantscale/datasets/blob/master/misc/xeek.csv?raw=true'

df = pd.read_csv(data_location)

# %%
df.sample(10)
# Out:
#             WELL     DEPTH_MD        X_LOC      Y_LOC        Z_LOC  \
# 7885  16/02/2016  1270.838396  476768.1563  6523588.5 -1244.473389
# 4800  16/10/2005  3005.396387  448702.0625  6429287.0 -2961.732178
# 7701  15/09/2015  1510.648000  436813.2188  6462992.0 -1485.607056
# 1088  16/10/2003   898.013599  460419.9063  6453750.5  -857.983398
# 6766    16/1-6 A  1504.299735  459498.7188  6539499.0 -1458.794312
# 793   16/10/2001  3045.303790  444183.5938  6435592.5 -3018.785889
# 5811    16/1-6 A  1484.387735  459498.8750  6539489.0 -1441.554321
# 1020  16/10/2003  1185.293599  460421.4688  6453750.5 -1145.254639
# 3137  15/09/2015  1402.424000  436813.1563  6462991.5 -1377.385620
# 3908  15/09/2015  3164.408000  436791.5313  6463020.5 -3138.837891
#
#               GROUP      FORMATION       CALI      RSHA      RMED  ...  \
# 7885  HORDALAND GP.      Skade Fm.  13.025021       NaN  0.980975  ...
# 4800   VESTLAND GP.        Ula Fm.   8.565857  0.459618  0.468449  ...
# 7701  HORDALAND GP.     Utsira Fm.  12.978481  1.081751  1.081751  ...
# 1088   NORDLAND GP.            NaN  22.099607  0.801121  0.807728  ...
# 6766  HORDALAND GP.      Skade Fm.  10.261952       NaN  0.812595  ...
# 793    VESTLAND GP.   Sleipner Fm.   8.757215       NaN  9.565025  ...
# 5811  HORDALAND GP.      Skade Fm.   9.145981       NaN  0.684793  ...
# 1020  HORDALAND GP.     Utsira Fm.  19.000000  1.045771  1.037182  ...
# 3137  HORDALAND GP.     Utsira Fm.  15.569045  1.375634  1.375634  ...
# 3908      HEGRE GP.  Skagerrak Fm.   7.777569  1.059785  1.059785  ...
#
#               GR      NPHI       PEF         DTC          SP        ROP  \
# 7885   80.802101  0.424647  3.660032  135.086578         NaN  34.428875
# 4800   45.866512  0.182784  5.485764   78.550262         NaN  63.526787
# 7701   83.132553  0.509378  2.055642  148.076767   65.637627  40.327324
# 1088  140.890625       NaN       NaN  141.630676  511.050995  13.380000
# 6766   46.578491  0.451373  4.274518  131.865585         NaN  12.950099
# 793    59.862045  0.524006  2.085828  113.038597  125.429794   5.423223
# 5811   65.262199  0.497212  4.406563  144.610886         NaN  57.375210
# 1020  125.381996       NaN       NaN  139.498917  512.586426  17.480000
# 3137   94.670097  0.484539  2.023046  145.921265   64.102379  64.066887
# 3908   75.448540  0.253362  3.897765   80.287895  131.185822  34.775253
#
#              DTS      DCAL      DRHO  LITHOFACIES
# 7885         NaN       NaN  0.007377        65000
# 4800  139.244919  0.065857  0.001727        30000
# 7701         NaN  0.728483  0.032598        65000
# 1088         NaN  4.599606       NaN        65000
# 6766         NaN       NaN       NaN        70000
# 793          NaN  0.257215  0.007071        90000
# 5811         NaN       NaN       NaN        65000
# 1020         NaN  1.500000       NaN        65030
# 3137         NaN  3.319044  0.022848        65000
# 3908         NaN -0.722431 -0.029236        65030
#
# [10 rows x 22 columns]

# %% [markdown]
# ## Pandas Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   WELL         10000 non-null  object
#  1   DEPTH_MD     10000 non-null  float64
#  2   X_LOC        9423 non-null   float64
#  3   Y_LOC        9423 non-null   float64
#  4   Z_LOC        9423 non-null   float64
#  5   GROUP        10000 non-null  object
#  6   FORMATION    8409 non-null   object
#  7   CALI         9991 non-null   float64
#  8   RSHA         4642 non-null   float64
#  9   RMED         9403 non-null   float64
#  10  RDEP         9423 non-null   float64
#  11  RHOB         8146 non-null   float64
#  12  GR           10000 non-null  float64
#  13  NPHI         6906 non-null   float64
#  14  PEF          7591 non-null   float64
#  15  DTC          9962 non-null   float64
#  16  SP           7002 non-null   float64
#  17  ROP          9784 non-null   float64
#  18  DTS          922 non-null    float64
#  19  DCAL         4170 non-null   float64
#  20  DRHO         7964 non-null   float64
#  21  LITHOFACIES  10000 non-null  int64
# dtypes: float64(18), int64(1), object(3)
# memory usage: 1.7+ MB

# %%
df.describe()
# Out:
#            DEPTH_MD          X_LOC         Y_LOC        Z_LOC         CALI  \
# count  10000.000000    9423.000000  9.423000e+03  9423.000000  9991.000000
# mean    1800.814415  451373.564917  6.471805e+06 -1724.794635    13.173323
# std      743.082546   15407.370351  3.090890e+04   744.201632     3.568595
# min      416.629599  436790.843800  6.429286e+06 -3245.397705     5.980328
# 25%     1176.451898  437640.781300  6.453744e+06 -2357.255615    11.102654
# 50%     1760.302694  444152.125000  6.463020e+06 -1628.729370    12.691269
# 75%     2439.283242  460445.031300  6.478966e+06 -1115.731812    14.883303
# max     3271.264000  476770.125000  6.539630e+06  -376.619446    23.703100
#
#               RSHA         RMED         RDEP         RHOB            GR  \
# count  4642.000000  9403.000000  9423.000000  8146.000000  10000.000000
# mean     12.563032     1.725687     1.648099     2.203431     69.501064
# std     130.472699     6.015278     3.627662     0.237323     39.467288
# min       0.130193     0.079855     0.123068     1.372443      0.189038
# 25%       0.761883     0.782991     0.783729     2.029909     42.506623
# 50%       1.022285     1.107877     1.138458     2.167345     65.723911
# 75%       1.521705     1.565433     1.665577     2.407537     94.200748
# max    2044.732788   402.169128   161.391007     3.107460    574.036926
#
#               NPHI          PEF          DTC           SP          ROP  \
# count  6906.000000  7591.000000  9962.000000  7002.000000  9784.000000
# mean      0.352055     4.469773   122.254397    92.683717    28.518905
# std       0.144581     5.496938    34.314742   100.862046    53.423323
# min      -0.021050     1.028746     7.812520    -1.982743     0.029830
# 25%       0.231541     2.863662    87.500502    48.834332     9.433549
# 50%       0.376831     3.801839   135.592278    70.623707    22.384808
# 75%       0.478592     5.084510   147.443314    92.791689    35.680258
# max       0.665642   365.575592   206.641403   526.153198  2224.647461
#
#               DTS         DCAL         DRHO   LITHOFACIES
# count  922.000000  4170.000000  7964.000000  10000.000000
# mean   176.159537     0.760177     0.009391  63220.527600
# std     41.840200     1.763075     0.063463  13711.099797
# min     93.785995   -11.366377    -0.989495  30000.000000
# 25%    150.047756     0.007652    -0.007794  65000.000000
# 50%    163.398529     0.411437     0.003360  65000.000000
# 75%    191.983746     1.058703     0.022866  65030.000000
# max    340.204834    11.203100     0.251427  99000.000000

# %%
df.isnull().sum()
# Out:
# WELL              0
# DEPTH_MD          0
# X_LOC           577
# Y_LOC           577
# Z_LOC           577
# GROUP             0
# FORMATION      1591
# CALI              9
# RSHA           5358
# RMED            597
# RDEP            577
# RHOB           1854
# GR                0
# NPHI           3094
# PEF            2409
# DTC              38
# SP             2998
# ROP             216
# DTS            9078
# DCAL           5830
# DRHO           2036
# LITHOFACIES       0
# dtype: int64

# %% [markdown]
# ## Missing No

# %%
import missingno as msno

# %matplotlib inline

# %%
msno.matrix(df)
# Out:
# <AxesSubplot: >

# %%
msno.bar(df)
# Out:
# <AxesSubplot: >

# %%
msno.heatmap(df)
# Out:
# <AxesSubplot: >
