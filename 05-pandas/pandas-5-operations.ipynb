# %% [markdown]
# ## Dataframe Operations
#
# We will look at some common operations

# %%
import pandas as pd
import numpy as np

#pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Step 1 - Load AirBnb Data

# %%
data_location = '../data/AB_NYC_2019.csv'
# data_location = 'https://github.com/elephantscale/datasets/blob/master/airbnb/AB_NYC_2019.csv?raw=true'

airbnb = pd.read_csv(data_location)

# %% [markdown]
# ## Step 2 - Display the Dataframe
#
# ### 2.1 - First / last few rows
#
# Just specify `airbnb` at a cell

# %%
airbnb
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### 2.2 - Display First few rows - `head`

# %%
# display first 5 rows
airbnb.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### 2.3 - Display a sample of data - `sample`
#
# **This is my personal goto, why?  it gives you a glimpse of the data.  not just the first few rows**

# %%
# 5 sample rows
airbnb.sample(5)

# see how the indexes are randomly selected
# Out:
#              id                                 name   host_id  host_name  \
# 13517  10115792   3 Bedroom Luxury Apartment on 33rd  48784045       Jake
# 1892     839539  Awesome, Unique EAST VILLAGE LOFT!!   3200135       Matt
# 44792  34401906            New York Modern Apartment  34075689  Zhen Zhen
# 6452    4699061   Cosy room in Brooklyn!2min to Sbwy  24291213      Joerg
# 3662    2203450     Perfect Location - 2 bdrm/2 bth    1500487      David
#
#       neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 13517           Manhattan      Kips Bay  40.74520  -73.97779  Entire home/apt
# 1892            Manhattan  East Village  40.72876  -73.98413     Private room
# 44792              Queens       Maspeth  40.72167  -73.90095  Entire home/apt
# 6452             Brooklyn   Sunset Park  40.64009  -74.01714     Private room
# 3662             Brooklyn  Williamsburg  40.71577  -73.95408  Entire home/apt
#
# ...

# %% [markdown]
# ## Step 3 - `Describe` is your friend
#
# It will show a quick summary of the df
#
# <span style="color:red">
# **spend some time going through the output**
#     </span>
#
# - **count** is non-null records per column

# %%
airbnb.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ## Step 4 - Creating another column
#
# Very easy!

# %%
## use a fixed value
airbnb['a'] = 100
airbnb.sample(5)
# Out:
#              id                                               name    host_id  \
# 23374  18916381          Large Park Slope Home with Private Garden    6252064
# 32151  25134894     Massive 4 bed 3 bath Loft in SoHo/Little Italy  189961241
# 36988  29410763        Hell's Kitchen Luxurious 2 Bedroom NYC Apt!  163251048
# 18292  14350781         West Village/SoHo - Small but Mighty Room!    7977178
# 2190    1023181  LOCATION/garden!(FEMALE only, next to girl's r...    4932354
#
#       host_name neighbourhood_group     neighbourhood  latitude  longitude  \
# 23374       Amy            Brooklyn       Sunset Park  40.65969  -73.99248
# 32151     Danny           Manhattan      Little Italy  40.71839  -73.99834
# 36988       Jen           Manhattan    Hell's Kitchen  40.76094  -73.99778
# 18292      Abby           Manhattan              SoHo  40.72770  -74.00375
# 2190      Mitty            Brooklyn  Prospect Heights  40.67870  -73.97065
#
# ...

# %%
## OR we can do a conditionals too

# if overnight rate is over 1000 , we mark it as too expensive

airbnb['too_expensive'] = airbnb['price'] > 1000
airbnb.sample(5)
# Out:
#              id                                            name   host_id  \
# 23116  18721027              Spacious NYC Apartment with a View  47485343
# 15404  12344949              Brand new luxury 2 br Harlem condo  33993577
# 2122     975229  Prime East Village location w/backyard garden!   5333736
# 23586  19083282                                      纽约干净大房近地铁站  51698646
# 43322  33583238  Lovely apartment 2 bedrooms 2 bathrooms in UWS  30137775
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 23116    Claire            Brooklyn      Sunset Park  40.65003  -74.00657
# 15404      Nick           Manhattan           Harlem  40.80882  -73.94654
# 2122    Timothy           Manhattan     East Village  40.73055  -73.98875
# 23586       Ivy              Queens        Sunnyside  40.74242  -73.92597
# 43322  Thibault           Manhattan  Upper West Side  40.79321  -73.96823
#
# ...

# %%
## only find the too expensive ones :-)

too_expensive = airbnb[airbnb['too_expensive'] == True]
print (too_expensive.shape[0])
too_expensive.sample(5)
# Out:
# 239
#              id                                               name    host_id  \
# 30080  23169146                            Artist apartment in LIC   51260506
# 47350  35706068                                   wait until later   35741633
# 26443  21047121                                  Murray Hill House   55527442
# 14574  11495797                1br Suite - St Regis Residence Club   60535711
# 39742  30927844  Cost-effective nice room near Columbia Univers...  138349238
#
#        host_name neighbourhood_group     neighbourhood  latitude  longitude  \
# 30080      Grace              Queens  Long Island City  40.74786  -73.94628
# 47350       Chen              Queens  Long Island City  40.74869  -73.94294
# 26443  Ekaterina           Manhattan       Murray Hill  40.74685  -73.97892
# 14574      Bruce           Manhattan           Midtown  40.76040  -73.97410
# 39742         韦达           Manhattan   Upper West Side  40.80146  -73.96076
#
# ...

# %% [markdown]
# ## Step  5 - Sorting Dataframes
#
# We can sort by any columns

# %%
## Let's sort by price

airbnb.sort_values(['price'], ascending=True).head(5)
# Out:
#              id                                               name    host_id  \
# 25796  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 25634  20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 25433  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 25753  20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 23161  18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
#
#           host_name neighbourhood_group       neighbourhood  latitude  \
# 25796       Adeyemi            Brooklyn  Bedford-Stuyvesant  40.68258
# 25634  Martial Loft            Brooklyn            Bushwick  40.69467
# 25433        Anisha               Bronx     East Morrisania  40.83296
# 25753        Lauren            Brooklyn          Greenpoint  40.72462
# 23161      Kimberly            Brooklyn  Bedford-Stuyvesant  40.69023
#
#        longitude     room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
# see the most expensive ones first

airbnb.sort_values(['price'], ascending=False).head(5)
# Out:
#              id                                               name   host_id  \
# 9151    7003697                Furnished room in Astoria apartment  20582832
# 17692  13894339    Luxury 1 bedroom apt. -stunning Manhattan views   5143901
# 29238  22436899                                1-BR Lincoln Center  72390391
# 40433  31340283  2br - The Heart of NYC: Manhattans Lower East ...   4382127
# 12342   9528920                Quiet, Clean, Lit @ LES & Chinatown   3906464
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 9151   Kathrine              Queens          Astoria  40.76810  -73.91651
# 17692      Erin            Brooklyn       Greenpoint  40.73260  -73.95739
# 29238    Jelena           Manhattan  Upper West Side  40.77213  -73.98665
# 40433      Matt           Manhattan  Lower East Side  40.71980  -73.98566
# 12342       Amy           Manhattan  Lower East Side  40.71355  -73.98507
#
# ...

# %%
## We can sort by multiple columns

airbnb.sort_values([ 'number_of_reviews', 'price'], ascending=False).head(5)
# Out:
#              id                            name   host_id host_name  \
# 11759   9145202         Room near JFK Queen Bed  47621202      Dona
# 2031     903972      Great Bedroom in Manhattan   4734398        Jj
# 2030     903947  Beautiful Bedroom in Manhattan   4734398        Jj
# 2015     891117    Private Bedroom in Manhattan   4734398        Jj
# 13495  10101135         Room Near JFK Twin Beds  47621202      Dona
#
#       neighbourhood_group neighbourhood  latitude  longitude     room_type  \
# 11759              Queens       Jamaica  40.66730  -73.76831  Private room
# 2031            Manhattan        Harlem  40.82085  -73.94025  Private room
# 2030            Manhattan        Harlem  40.82124  -73.93838  Private room
# 2015            Manhattan        Harlem  40.82264  -73.94041  Private room
# 13495              Queens       Jamaica  40.66939  -73.76975  Private room
#
#        price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ---
#
# ## Step 6 - Groupby Aggregates
#
# let's find min/max/mean prices for each borough

# %%
airbnb.groupby('neighbourhood_group').agg({'price': ['mean', 'min', 'max']})
# Out:
#                           price
#                            mean min    max
# neighbourhood_group
# Bronx                 87.496792   0   2500
# Brooklyn             124.383207   0  10000
# Manhattan            196.875814   0  10000
# Queens                99.517649  10  10000
# Staten Island        114.812332  13   5000

# %% [markdown]
# ## Step 7 - Find Distinct Value for columns
#
# This is handy for understanding dinstinc values

# %%
columns = ['neighbourhood_group', 'neighbourhood', 'room_type']

for col in columns:
    print (col)
    print (airbnb[col].value_counts())
    print ('-------')
# Out:
# neighbourhood_group
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64
# -------
# neighbourhood
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
#                       ...
# Fort Wadsworth           1
# Richmondtown             1
# New Dorp                 1
# Rossville                1
# Willowbrook              1
# Name: neighbourhood, Length: 221, dtype: int64
# -------
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64
# -------

# %% [markdown]
# ## Display Options
#
# You can play with these options
#
# ```python
# pd.set_option('display.max_columns', 200)
# pd.set_option('display.max_rows', 100)
# pd.set_option('display.min_rows', 100)
# ```
#
# References
# - https://towardsdatascience.com/8-commonly-used-pandas-display-options-you-should-know-a832365efa95

# %%
pd.set_option('display.float_format', '{:,.2f}'.format)
airbnb
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# reset display options
pd.reset_option('display.max_columns')
