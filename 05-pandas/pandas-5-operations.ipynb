# %% [markdown]
# ## Dataframe Operations
#
# We will look at some common operations

# %%
import pandas as pd
import numpy as np

#pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Step 1 - Load AirBnb Data

# %%
data_location = '../data/AB_NYC_2019.csv'
# data_location = 'https://github.com/elephantscale/datasets/blob/master/airbnb/AB_NYC_2019.csv?raw=true'

airbnb = pd.read_csv(data_location)

# %% [markdown]
# ## Step 2 - Display the Dataframe
#
# ### 2.1 - First / last few rows
#
# Just specify `airbnb` at a cell

# %%
airbnb
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.98377  Entire home/apt    225               1                 45
# 2      -73.94190     Private room    150               3                  0
# 3      -73.95976  Entire home/apt     89               1                270
# 4      -73.94399  Entire home/apt     80              10                  9
# ...          ...              ...    ...             ...                ...
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
# 48892  -73.94867  Entire home/apt    115              10                  0
# 48893  -73.99112      Shared room     55               1                  0
# 48894  -73.98933     Private room     90               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2018-10-19               0.21                               6
# 1      2019-05-21               0.38                               2
# 2             NaN                NaN                               1
# 3      2019-07-05               4.64                               1
# 4      2018-11-19               0.10                               1
# ...           ...                ...                             ...
# 48890         NaN                NaN                               2
# 48891         NaN                NaN                               2
# 48892         NaN                NaN                               1
# 48893         NaN                NaN                               6
# 48894         NaN                NaN                               1
#
#        availability_365
# 0                   365
# 1                   355
# 2                   365
# 3                   194
# 4                     0
# ...                 ...
# 48890                 9
# 48891                36
# 48892                27
# 48893                 2
# 48894                23
#
# [48895 rows x 16 columns]

# %% [markdown]
# ### 2.2 - Display First few rows - `head`

# %%
# display first 5 rows
airbnb.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %% [markdown]
# ### 2.3 - Display a sample of data - `sample`
#
# **This is my personal goto, why?  it gives you a glimpse of the data.  not just the first few rows**

# %%
# 5 sample rows
airbnb.sample(5)

# see how the indexes are randomly selected
# Out:
#              id                                               name   host_id  \
# 12700   9733280                  Quiet, 1 Bedroom, Patio, Gramercy  11763414
# 23521  19044895  Private room in 2br apartment near subway (train)  85526404
# 29137  22374957   Williamsburg 4 Bedroom - Spacious Warehouse Loft  41218193
# 10543   8090529                        Modern studio in Queens, NY  17377835
# 13499  10101791                              Private Room for Rent  51839283
#
#                host_name neighbourhood_group       neighbourhood  latitude  \
# 12700             Ashley           Manhattan            Gramercy  40.73606
# 23521  Zakir And Shagraf              Queens            Flushing  40.75448
# 29137              Tommy            Brooklyn        Williamsburg  40.72030
# 10543               Alex              Queens           Sunnyside  40.74674
# 13499             Ashley           Manhattan  Washington Heights  40.85064
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 12700  -73.98242  Entire home/apt    149               7                 13
# 23521  -73.82295     Private room     55               1                 37
# 29137  -73.95739  Entire home/apt    500               1                  0
# 10543  -73.91881  Entire home/apt    250               3                  0
# 13499  -73.93833     Private room     75               1                  1
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 12700  2018-04-03               0.33                               1
# 23521  2018-07-25               1.46                               1
# 29137         NaN                NaN                               1
# 10543         NaN                NaN                               1
# 13499  2016-01-02               0.02                               1
#
#        availability_365
# 12700                 0
# 23521                 0
# 29137                 0
# 10543               364
# 13499                 0

# %% [markdown]
# ## `Describe` is your friend
#
# It will show a quick summary of the df
#
# <span style="color:red">
# **spend some time going through the output**
#     </span>
#
# - **count** is non-null records per column

# %%
airbnb.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          3.000000           5.000000           0.720000
# 75%          5.000000          24.000000           2.020000
# max       1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# std                         32.952519        131.622289
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         45.000000
# 75%                          2.000000        227.000000
# max                        327.000000        365.000000

# %% [markdown]
# ## Creating another column
#
# Very easy!

# %%
## use a fixed value
airbnb['a'] = 100
airbnb.sample(5)
# Out:
#              id                                          name   host_id  \
# 25587  20482768   Cozy stay in Brooklyn (Sheepshead Bay Area)  35040795
# 36589  29093302                       Cozy quiet private room  41939513
# 14419  11304325                             West Village 2 Br  59095370
# 7456    5557097  A private room in New York. One block from A   3447539
# 9265    7084130                      Large Sunny Private Room  22095455
#
#        host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 25587     Sergii            Brooklyn      Sheepshead Bay  40.58779  -73.94703
# 36589    Cynthia           Manhattan              Harlem  40.79913  -73.95357
# 14419  Gabriella           Manhattan        West Village  40.73313  -74.00336
# 7456        Nick           Manhattan  Washington Heights  40.84898  -73.93642
# 9265       Danni           Manhattan        Civic Center  40.71674  -74.00334
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 25587     Private room     70               1                  0         NaN
# 36589     Private room    120               5                  3  2018-12-09
# 14419  Entire home/apt    250               1                  1  2016-02-25
# 7456      Private room     59               4                109  2019-06-27
# 9265      Private room    100               5                  1  2015-08-03
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 25587                NaN                               1                 0
# 36589               0.38                               1                 0
# 14419               0.02                               1                 0
# 7456                2.08                               2               284
# 9265                0.02                               1                 0
#
#          a
# 25587  100
# 36589  100
# 14419  100
# 7456   100
# 9265   100

# %%
## OR we can do a conditionals too

# if overnight rate is over 1000 , we mark it as too expensive

airbnb['too_expensive'] = airbnb['price'] > 1000
airbnb.sample(5)
# Out:
#              id                                             name   host_id  \
# 12229   9474607               Brand new apt in heart of Midtown!  43951918
# 32089  25069823                Riverside Drive Condo with a View  69866875
# 13586  10163240                Private room in 3 br in Manhattan  41535999
# 2674    1427518  Spacious, amenity-filled 1 BDR Williamsburg Apt   7654662
# 16614  13296897             Beautiful Bedroom Mid Town Manhattan  54454582
#
#            host_name neighbourhood_group        neighbourhood  latitude  \
# 12229           Mian           Manhattan       Hell's Kitchen  40.75553
# 32089       Georgina           Manhattan               Harlem  40.83298
# 13586          Amber           Manhattan  Morningside Heights  40.80348
# 2674       Elizabeth            Brooklyn         Williamsburg  40.71385
# 16614  Breath Beyond           Manhattan       Hell's Kitchen  40.76283
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 12229  -73.99230  Entire home/apt    280               4                  0
# 32089  -73.94800     Private room    100               7                  1
# 13586  -73.96320     Private room     70               1                  1
# 2674   -73.93861  Entire home/apt    160               6                  1
# 16614  -73.99331     Private room    115               2                 30
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 12229         NaN                NaN                               1
# 32089  2018-05-15               0.07                               1
# 13586  2016-01-12               0.02                               1
# 2674   2013-09-07               0.01                               1
# 16614  2019-07-02               0.80                               3
#
#        availability_365    a  too_expensive
# 12229                 0  100          False
# 32089                 0  100          False
# 13586                 0  100          False
# 2674                  0  100          False
# 16614                 3  100          False

# %%
## only find the too expensive ones :-)

too_expensive = airbnb[airbnb['too_expensive'] == True]
print (too_expensive.shape[0])
too_expensive.sample(5)
# Out:
# 239
#              id                                               name    host_id  \
# 3306    1976123                    Huge Loft with Private Entrance    6547579
# 38947  30443976                                Times Square Palace  193986289
# 34844  27627627                               New York Condominium    3250725
# 48523  36308562  Tasteful & Trendy Brooklyn Brownstone, near Train  217732163
# 23584  19081969    Beautiful Private Townhouse- Heart of Manhattan   21810947
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 3306       Josh           Manhattan        East Village  40.72823  -73.98933
# 38947      Greg           Manhattan    Theater District  40.76006  -73.98589
# 34844       Ken           Manhattan                SoHo  40.72060  -74.00330
# 48523     Sandy            Brooklyn  Bedford-Stuyvesant  40.68767  -73.95805
# 23584     Ellen           Manhattan             Midtown  40.75488  -73.97134
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 3306   Entire home/apt   1999               1                 20  2015-08-20
# 38947  Entire home/apt   3000               1                  0         NaN
# 34844  Entire home/apt   1100               3                  5  2018-12-27
# 48523  Entire home/apt   1369               1                  0         NaN
# 23584  Entire home/apt   1200               7                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 3306                0.39                               1                 0
# 38947                NaN                               1               311
# 34844               0.52                               1               180
# 48523                NaN                               1               349
# 23584                NaN                               1                 0
#
#          a  too_expensive
# 3306   100           True
# 38947  100           True
# 34844  100           True
# 48523  100           True
# 23584  100           True

# %% [markdown]
# ## Sorting Dataframes
#
# We can sort by any columns

# %%
## Let's sort by price

airbnb.sort_values(['price'], ascending=True).head(5)
# Out:
#              id                                               name    host_id  \
# 25796  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 25634  20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 25433  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 25753  20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 23161  18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
#
#           host_name neighbourhood_group       neighbourhood  latitude  \
# 25796       Adeyemi            Brooklyn  Bedford-Stuyvesant  40.68258
# 25634  Martial Loft            Brooklyn            Bushwick  40.69467
# 25433        Anisha               Bronx     East Morrisania  40.83296
# 25753        Lauren            Brooklyn          Greenpoint  40.72462
# 23161      Kimberly            Brooklyn  Bedford-Stuyvesant  40.69023
#
#        longitude     room_type  price  minimum_nights  number_of_reviews  \
# 25796  -73.91284  Private room      0               1                 95
# 25634  -73.92433  Private room      0               2                 16
# 25433  -73.88668  Private room      0               2                 55
# 25753  -73.94072  Private room      0               2                 12
# 23161  -73.95428  Private room      0               4                  1
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 25796  2019-06-23               4.35                               6
# 25634  2019-05-18               0.71                               5
# 25433  2019-06-24               2.56                               4
# 25753  2017-10-27               0.53                               2
# 23161  2018-01-06               0.05                               4
#
#        availability_365    a  too_expensive
# 25796               222  100          False
# 25634                 0  100          False
# 25433               127  100          False
# 25753                 0  100          False
# 23161                28  100          False

# %%
# see the most expensive ones first

airbnb.sort_values(['price'], ascending=False).head(5)
# Out:
#              id                                               name   host_id  \
# 9151    7003697                Furnished room in Astoria apartment  20582832
# 17692  13894339    Luxury 1 bedroom apt. -stunning Manhattan views   5143901
# 29238  22436899                                1-BR Lincoln Center  72390391
# 40433  31340283  2br - The Heart of NYC: Manhattans Lower East ...   4382127
# 12342   9528920                Quiet, Clean, Lit @ LES & Chinatown   3906464
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 9151   Kathrine              Queens          Astoria  40.76810  -73.91651
# 17692      Erin            Brooklyn       Greenpoint  40.73260  -73.95739
# 29238    Jelena           Manhattan  Upper West Side  40.77213  -73.98665
# 40433      Matt           Manhattan  Lower East Side  40.71980  -73.98566
# 12342       Amy           Manhattan  Lower East Side  40.71355  -73.98507
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 9151      Private room  10000             100                  2  2016-02-13
# 17692  Entire home/apt  10000               5                  5  2017-07-27
# 29238  Entire home/apt  10000              30                  0         NaN
# 40433  Entire home/apt   9999              30                  0         NaN
# 12342     Private room   9999              99                  6  2016-01-01
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 9151                0.04                               1                 0
# 17692               0.16                               1                 0
# 29238                NaN                               1                83
# 40433                NaN                               1               365
# 12342               0.14                               1                83
#
#          a  too_expensive
# 9151   100           True
# 17692  100           True
# 29238  100           True
# 40433  100           True
# 12342  100           True

# %%
## We can sort by multiple columns

airbnb.sort_values([ 'number_of_reviews', 'price'], ascending=False).head(5)
# Out:
#              id                            name   host_id host_name  \
# 11759   9145202         Room near JFK Queen Bed  47621202      Dona
# 2031     903972      Great Bedroom in Manhattan   4734398        Jj
# 2030     903947  Beautiful Bedroom in Manhattan   4734398        Jj
# 2015     891117    Private Bedroom in Manhattan   4734398        Jj
# 13495  10101135         Room Near JFK Twin Beds  47621202      Dona
#
#       neighbourhood_group neighbourhood  latitude  longitude     room_type  \
# 11759              Queens       Jamaica  40.66730  -73.76831  Private room
# 2031            Manhattan        Harlem  40.82085  -73.94025  Private room
# 2030            Manhattan        Harlem  40.82124  -73.93838  Private room
# 2015            Manhattan        Harlem  40.82264  -73.94041  Private room
# 13495              Queens       Jamaica  40.66939  -73.76975  Private room
#
#        price  minimum_nights  number_of_reviews last_review  \
# 11759     47               1                629  2019-07-05
# 2031      49               1                607  2019-06-21
# 2030      49               1                597  2019-06-23
# 2015      49               1                594  2019-06-15
# 13495     47               1                576  2019-06-27
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 11759              14.58                               2               333
# 2031                7.75                               3               293
# 2030                7.72                               3               342
# 2015                7.57                               3               339
# 13495              13.40                               2               173
#
#          a  too_expensive
# 11759  100          False
# 2031   100          False
# 2030   100          False
# 2015   100          False
# 13495  100          False

# %% [markdown]
# ---
#
# ## Groupby Aggregates
#
# let's find min/max/mean prices for each borough

# %%
airbnb.groupby('neighbourhood_group').agg({'price': ['mean', 'min', 'max']})
# Out:
#                           price
#                            mean min    max
# neighbourhood_group
# Bronx                 87.496792   0   2500
# Brooklyn             124.383207   0  10000
# Manhattan            196.875814   0  10000
# Queens                99.517649  10  10000
# Staten Island        114.812332  13   5000

# %% [markdown]
# ## Display Options
#
# You can play with these options
#
# ```python
# pd.set_option('display.max_columns', 200)
# pd.set_option('display.max_rows', 100)
# pd.set_option('display.min_rows', 100)
# ```
#
# References
# - https://towardsdatascience.com/8-commonly-used-pandas-display-options-you-should-know-a832365efa95

# %%
pd.set_option('display.max_columns', 200)
airbnb
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.98377  Entire home/apt    225               1                 45
# 2      -73.94190     Private room    150               3                  0
# 3      -73.95976  Entire home/apt     89               1                270
# 4      -73.94399  Entire home/apt     80              10                  9
# ...          ...              ...    ...             ...                ...
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
# 48892  -73.94867  Entire home/apt    115              10                  0
# 48893  -73.99112      Shared room     55               1                  0
# 48894  -73.98933     Private room     90               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      2018-10-19               0.21                               6
# 1      2019-05-21               0.38                               2
# 2             NaN                NaN                               1
# 3      2019-07-05               4.64                               1
# 4      2018-11-19               0.10                               1
# ...           ...                ...                             ...
# 48890         NaN                NaN                               2
# 48891         NaN                NaN                               2
# 48892         NaN                NaN                               1
# 48893         NaN                NaN                               6
# 48894         NaN                NaN                               1
#
#        availability_365    a  too_expensive
# 0                   365  100          False
# 1                   355  100          False
# 2                   365  100          False
# 3                   194  100          False
# 4                     0  100          False
# ...                 ...  ...            ...
# 48890                 9  100          False
# 48891                36  100          False
# 48892                27  100          False
# 48893                 2  100          False
# 48894                23  100          False
#
# [48895 rows x 18 columns]

# %%
# reset display options
pd.reset_option('display.max_columns')
